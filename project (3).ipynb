# %% [markdown]
# # My Project
#
# Welcome to this Jupyter notebook project!

# %%
# Example code cell
print('Hello, World!')
x = 42
print(f'The answer is: {x}')

# %% [markdown]
# ## Section 2
#
# You can add more content here.

# %%
# Another code cell
import pandas as pd
import numpy as np

# Create sample data
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35]}
df = pd.DataFrame(data)
print(df)
